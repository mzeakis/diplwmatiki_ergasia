# %%
import os
import pydub
from pydub import AudioSegment

pydub.AudioSegment.converter = r"C:\ffmpeg\bin\ffmpeg.exe"

#path = "C:/users/Michalis Zeakis/Desktop/university/ptyxiaki/datasets/our_dataset"
path = "C:/Users/Michalis Zeakis/Desktop/university/ptyxiaki/datasets/test_dataset_mp3"

#Change working directory
os.chdir(path)

audio_files = os.listdir()

#print(audio_files, len(audio_files))
# You dont need the number of files in the folder, just iterate over them directly using:
for file in audio_files:
    #print(file)
    
    #spliting the file into the name and the extension
    name, ext = os.path.splitext(file)
    mp3_sound = AudioSegment.from_mp3(file)
       #rename them using the old name + ".wav"
    mp3_sound.export("C:/Users/Michalis Zeakis/Desktop/university/ptyxiaki/datasets/test_dataset_wav/{0}.wav".format(name), format="wav")

print("Done !!")
# Out:
# ---------------------------------------------------------------------------
# CouldntDecodeError                        Traceback (most recent call last)
# <ipython-input-25-3ea4aabcd332> in <module>
#      23     #print(sound_type.type)
#      24     #mp3_sound = AudioSegment.from_mp3(file)
# ---> 25     aac_sound = AudioSegment.from_file(file, format = 'aac')
#      26
#      27        #rename them using the old name + ".wav"
#
# C:\anaconda3\lib\site-packages\pydub\audio_segment.py in from_file(cls, file, format, codec, parameters, start_second, duration, **kwargs)
#     771             if close_file:
#     772                 file.close()
# --> 773             raise CouldntDecodeError(
#     774                 "Decoding failed. ffmpeg returned error code: {0}\n\nOutput from ffmpeg/avlib:\n\n{1}".format(
#     775                     p.returncode, p_err.decode(errors='ignore') ))
#
# CouldntDecodeError: Decoding failed. ffmpeg returned error code: 1
#
# Output from ffmpeg/avlib:
#
# ffmpeg version 2021-06-16-git-604924a069-full_build-www.gyan.dev Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 10.3.0 (Rev2, Built by MSYS2 project)
#   configuration: --enable-gpl --enable-version3 --enable-static --disable-w32threads --disable-autodetect --enable-fontconfig --enable-iconv --enable-gnutls --enable-libxml2 --enable-gmp --enable-lzma --enable-libsnappy --enable-zlib --enable-librist --enable-libsrt --enable-libssh --enable-libzmq --enable-avisynth --enable-libbluray --enable-libcaca --enable-sdl2 --enable-libdav1d --enable-libzvbi --enable-librav1e --enable-libsvtav1 --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxvid --enable-libaom --enable-libopenjpeg --enable-libvpx --enable-libass --enable-frei0r --enable-libfreetype --enable-libfribidi --enable-libvidstab --enable-libvmaf --enable-libzimg --enable-amf --enable-cuda-llvm --enable-cuvid --enable-ffnvcodec --enable-nvdec --enable-nvenc --enable-d3d11va --enable-dxva2 --enable-libmfx --enable-libglslang --enable-vulkan --enable-opencl --enable-libcdio --enable-libgme --enable-libmodplug --enable-libopenmpt --enable-libopencore-amrwb --enable-libmp3lame --enable-libshine --enable-libtheora --enable-libtwolame --enable-libvo-amrwbenc --enable-libilbc --enable-libgsm --enable-libopencore-amrnb --enable-libopus --enable-libspeex --enable-libvorbis --enable-ladspa --enable-libbs2b --enable-libflite --enable-libmysofa --enable-librubberband --enable-libsoxr --enable-chromaprint
#   libavutil      57.  0.100 / 57.  0.100
#   libavcodec     59.  1.101 / 59.  1.101
#   libavformat    59.  3.100 / 59.  3.100
#   libavdevice    59.  0.100 / 59.  0.100
#   libavfilter     8.  0.102 /  8.  0.102
#   libswscale      6.  0.100 /  6.  0.100
#   libswresample   4.  0.100 /  4.  0.100
#   libpostproc    56.  0.100 / 56.  0.100
# [aac @ 0000026f7be58440] More than one AAC RDB per ADTS frame is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] Assuming an incorrectly encoded 7.1 channel layout instead of a spec-compliant 7.1(wide) layout, use -strict 1 to decode according to the specification instead.
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Multiple frames in a packet.
# [aac @ 0000026f7be58440] channel element 3.7 is not allocated
# [aac @ 0000026f7be58440] channel element 3.9 is not allocated
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] channel element 2.8 is not allocated
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] channel element 2.13 is not allocated
# [aac @ 0000026f7be58440] channel element 2.8 is not allocated
# [aac @ 0000026f7be58440] channel element 1.12 is not allocated
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] channel element 2.0 is not allocated
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Reserved bit set.
# [aac @ 0000026f7be58440] Number of bands (23) exceeds limit (21).
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] channel element 2.0 is not allocated
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] Reserved bit set.
# [aac @ 0000026f7be58440] Number of bands (8) exceeds limit (5).
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] channel element 2.4 is not allocated
# [aac @ 0000026f7be58440] channel element 3.4 is not allocated
# [aac @ 0000026f7be58440] channel element 0.3 is not allocated
# [aac @ 0000026f7be58440] SBR was found before the first channel element.
# [aac @ 0000026f7be58440] Number of scalefactor bands in group (14) exceeds limit (12).
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] Number of bands (13) exceeds limit (6).
# [aac @ 0000026f7be58440] channel element 3.0 is not allocated
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] channel element 3.7 is not allocated
# [aac @ 0000026f7be58440] channel element 3.1 is not allocated
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] channel element 3.7 is not allocated
# [aac @ 0000026f7be58440] Pulse data corrupt or invalid.
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] channel element 2.7 is not allocated
# [aac @ 0000026f7be58440] Number of bands (19) exceeds limit (2).
# [aac @ 0000026f7be58440] Dependent coupling is not supported together with LTP
#     Last message repeated 17 times
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] channel element 2.8 is not allocated
# [aac @ 0000026f7be58440] Reserved bit set.
# [aac @ 0000026f7be58440] Number of bands (37) exceeds limit (21).
# [aac @ 0000026f7be58440] channel element 1.13 is not allocated
# [aac @ 0000026f7be58440] Number of bands (18) exceeds limit (17).
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Too large remapped id is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] TNS filter order 27 is greater than maximum 20.
# [aac @ 0000026f7be58440] Number of bands (33) exceeds limit (9).
# [aac @ 0000026f7be58440] channel element 3.6 is not allocated
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Too large remapped id is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] channel element 2.9 is not allocated
# [aac @ 0000026f7be58440] Reserved bit set.
# [aac @ 0000026f7be58440] Number of bands (13) exceeds limit (8).
# [aac @ 0000026f7be58440] channel element 2.10 is not allocated
# [aac @ 0000026f7be58440] channel element 3.0 is not allocated
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] Number of scalefactor bands in group (15) exceeds limit (14).
# [aac @ 0000026f7be58440] channel element 2.2 is not allocated
# [aac @ 0000026f7be58440] channel element 2.1 is not allocated
# [aac @ 0000026f7be58440] channel element 1.6 is not allocated
# [aac @ 0000026f7be58440] Dependent coupling is not supported together with LTP
#     Last message repeated 17 times
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Too large remapped id is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] channel element 2.2 is not allocated
# [aac @ 0000026f7be58440] Reserved bit set.
# [aac @ 0000026f7be58440] Number of bands (34) exceeds limit (27).
# [aac @ 0000026f7be58440] Dependent coupling is not supported together with LTP
#     Last message repeated 17 times
# [aac @ 0000026f7be58440] SBR was found before the first channel element.
# [aac @ 0000026f7be58440] Number of scalefactor bands in group (56) exceeds limit (40).
# [aac @ 0000026f7be58440] Number of scalefactor bands in group (50) exceeds limit (47).
# [aac @ 0000026f7be58440] channel element 3.6 is not allocated
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Dependent coupling is not supported together with LTP
#     Last message repeated 17 times
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] decode_pce: Input buffer exhausted before END element found
# [aac @ 0000026f7be58440] channel element 2.15 is not allocated
# [aac @ 0000026f7be58440] channel element 3.3 is not allocated
# [aac @ 0000026f7be58440] channel element 3.0 is not allocated
# [aac @ 0000026f7be58440] Number of bands (19) exceeds limit (13).
# [aac @ 0000026f7be58440] Reserved bit set.
# [aac @ 0000026f7be58440] Number of bands (25) exceeds limit (5).
# [aac @ 0000026f7be58440] If you heard an audible artifact, there may be a bug in the decoder. Clipped noise gain (158 -> 155) is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] If you heard an audible artifact, there may be a bug in the decoder. Clipped noise gain (158 -> 155) is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] If you heard an audible artifact, there may be a bug in the decoder. Clipped noise gain (157 -> 155) is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] If you heard an audible artifact, there may be a bug in the decoder. Clipped noise gain (156 -> 155) is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] If you heard an audible artifact, there may be a bug in the decoder. Clipped noise gain (156 -> 155) is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] If you heard an audible artifact, there may be a bug in the decoder. Clipped noise gain (156 -> 155) is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] If you heard an audible artifact, there may be a bug in the decoder. Clipped noise gain (160 -> 155) is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] If you heard an audible artifact, there may be a bug in the decoder. Clipped noise gain (160 -> 155) is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] If you heard an audible artifact, there may be a bug in the decoder. Clipped noise gain (158 -> 155) is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] If you heard an audible artifact, there may be a bug in the decoder. Clipped noise gain (158 -> 155) is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] If you heard an audible artifact, there may be a bug in the decoder. Clipped noise gain (158 -> 155) is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] If you heard an audible artifact, there may be a bug in the decoder. Clipped noise gain (156 -> 155) is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] If you heard an audible artifact, there may be a bug in the decoder. Clipped noise gain (158 -> 155) is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] channel element 0.14 is not allocated
# [aac @ 0000026f7be58440] channel element 2.3 is not allocated
# [aac @ 0000026f7be58440] channel element 1.3 is not allocated
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] SBR was found before the first channel element.
# [aac @ 0000026f7be58440] Number of bands (13) exceeds limit (12).
# [aac @ 0000026f7be58440] Reserved bit set.
# [aac @ 0000026f7be58440] Number of bands (24) exceeds limit (20).
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] Reserved bit set.
# [aac @ 0000026f7be58440] Number of bands (31) exceeds limit (15).
# [aac @ 0000026f7be58440] channel element 3.0 is not allocated
# [aac @ 0000026f7be58440] channel element 1.0 is not allocated
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] channel element 2.11 is not allocated
# [aac @ 0000026f7be58440] Number of bands (7) exceeds limit (6).
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Too large remapped id is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] invalid band type
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] channel element 1.0 is not allocated
# [aac @ 0000026f7be58440] channel element 3.5 is not allocated
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Too large remapped id is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Too large remapped id is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] channel element 3.11 is not allocated
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] channel element 2.6 is not allocated
# [aac @ 0000026f7be58440] channel element 3.8 is not allocated
# [aac @ 0000026f7be58440] channel element 1.12 is not allocated
# [aac @ 0000026f7be58440] Dependent coupling is not supported together with LTP
#     Last message repeated 15 times
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] channel element 3.6 is not allocated
# [aac @ 0000026f7be58440] channel element 2.14 is not allocated
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] channel element 3.14 is not allocated
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] channel element 3.3 is not allocated
# [aac @ 0000026f7be58440] channel element 3.13 is not allocated
# [aac @ 0000026f7be58440] channel element 1.9 is not allocated
# [aac @ 0000026f7be58440] Prediction is not allowed in AAC-LC.
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] channel element 1.5 is not allocated
# [aac @ 0000026f7be58440] Reserved bit set.
# [aac @ 0000026f7be58440] Number of bands (37) exceeds limit (24).
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] channel element 1.9 is not allocated
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Too large remapped id is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] channel element 2.11 is not allocated
# [aac @ 0000026f7be58440] channel element 3.6 is not allocated
# [aac @ 0000026f7be58440] Reserved bit set.
# [aac @ 0000026f7be58440] Number of scalefactor bands in group (63) exceeds limit (41).
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] channel element 1.7 is not allocated
# [aac @ 0000026f7be58440] channel element 2.2 is not allocated
# [aac @ 0000026f7be58440] channel element 1.6 is not allocated
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] Number of bands (41) exceeds limit (32).
# [aac @ 0000026f7be58440] channel element 2.2 is not allocated
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Too large remapped id is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Too large remapped id is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] Reserved bit set.
# [aac @ 0000026f7be58440] Number of bands (48) exceeds limit (35).
# [aac @ 0000026f7be58440] channel element 1.7 is not allocated
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] channel element 1.8 is not allocated
# [aac @ 0000026f7be58440] channel element 1.7 is not allocated
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] channel element 1.0 is not allocated
# [aac @ 0000026f7be58440] channel element 2.4 is not allocated
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] invalid band type
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] Too large remapped id is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Reserved bit set.
# [aac @ 0000026f7be58440] Number of bands (33) exceeds limit (12).
# [aac @ 0000026f7be58440] channel element 3.12 is not allocated
# [aac @ 0000026f7be58440] Reserved bit set.
# [aac @ 0000026f7be58440] Number of scalefactor bands in group (61) exceeds limit (41).
# [aac @ 0000026f7be58440] channel element 1.6 is not allocated
# [aac @ 0000026f7be58440] channel element 3.6 is not allocated
# [aac @ 0000026f7be58440] SBR was found before the first channel element.
# [aac @ 0000026f7be58440] channel element 2.9 is not allocated
# [aac @ 0000026f7be58440] Number of bands (48) exceeds limit (45).
# [aac @ 0000026f7be58440] Reserved bit set.
# [aac @ 0000026f7be58440] Number of bands (17) exceeds limit (15).
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Too large remapped id is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] channel element 2.4 is not allocated
# [aac @ 0000026f7be58440] channel element 3.6 is not allocated
# [aac @ 0000026f7be58440] channel element 3.4 is not allocated
# [aac @ 0000026f7be58440] channel element 2.11 is not allocated
# [aac @ 0000026f7be58440] invalid band type
# [aac @ 0000026f7be58440] channel element 3.8 is not allocated
# [aac @ 0000026f7be58440] channel element 1.9 is not allocated
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] channel element 2.10 is not allocated
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] channel element 2.1 is not allocated
# [aac @ 0000026f7be58440] channel element 2.8 is not allocated
# [aac @ 0000026f7be58440] Reserved bit set.
# [aac @ 0000026f7be58440] Number of scalefactor bands in group (41) exceeds limit (40).
# [aac @ 0000026f7be58440] Number of bands (13) exceeds limit (9).
# [aac @ 0000026f7be58440] SBR was found before the first channel element.
# [aac @ 0000026f7be58440] Dependent coupling is not supported together with LTP
# [aac @ 0000026f7be58440] Reserved bit set.
# [aac @ 0000026f7be58440] Number of bands (24) exceeds limit (17).
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] Reserved bit set.
# [aac @ 0000026f7be58440] Number of bands (5) exceeds limit (1).
# [aac @ 0000026f7be58440] channel element 1.7 is not allocated
# [aac @ 0000026f7be58440] channel element 2.2 is not allocated
# [aac @ 0000026f7be58440] Reserved bit set.
# [aac @ 0000026f7be58440] Number of bands (6) exceeds limit (3).
# [aac @ 0000026f7be58440] channel element 3.15 is not allocated
# [aac @ 0000026f7be58440] Reserved bit set.
# [aac @ 0000026f7be58440] Number of scalefactor bands in group (46) exceeds limit (40).
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] channel element 1.5 is not allocated
# [aac @ 0000026f7be58440] channel element 2.12 is not allocated
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] channel element 0.0 is not allocated
# [aac @ 0000026f7be58440] channel element 2.10 is not allocated
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Number of bands (41) exceeds limit (17).
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] channel element 2.4 is not allocated
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] Number of bands (32) exceeds limit (21).
# [aac @ 0000026f7be58440] channel element 2.9 is not allocated
# [aac @ 0000026f7be58440] Number of bands (9) exceeds limit (8).
# [aac @ 0000026f7be58440] Reserved bit set.
# [aac @ 0000026f7be58440] Number of bands (17) exceeds limit (14).
# [aac @ 0000026f7be58440] SBR was found before the first channel element.
# [aac @ 0000026f7be58440] channel element 3.8 is not allocated
# [aac @ 0000026f7be58440] channel element 1.15 is not allocated
# [aac @ 0000026f7be58440] channel element 3.0 is not allocated
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] channel element 3.0 is not allocated
# [aac @ 0000026f7be58440] channel element 1.4 is not allocated
# [aac @ 0000026f7be58440] channel element 3.0 is not allocated
# [aac @ 0000026f7be58440] channel element 2.0 is not allocated
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] Dependent coupling is not supported together with LTP
#     Last message repeated 23 times
# [aac @ 0000026f7be58440] channel element 3.0 is not allocated
# [aac @ 0000026f7be58440] channel element 2.0 is not allocated
# [aac @ 0000026f7be58440] channel element 2.11 is not allocated
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] channel element 3.4 is not allocated
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] Number of bands (10) exceeds limit (1).
# [aac @ 0000026f7be58440] channel element 1.11 is not allocated
# [aac @ 0000026f7be58440] channel element 2.0 is not allocated
# [aac @ 0000026f7be58440] Reserved bit set.
# [aac @ 0000026f7be58440] Number of bands (41) exceeds limit (36).
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] channel element 1.4 is not allocated
# [aac @ 0000026f7be58440] Too large remapped id is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] channel element 3.8 is not allocated
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] channel element 3.13 is not allocated
# [aac @ 0000026f7be58440] ms_present = 3 is reserved.
# [aac @ 0000026f7be58440] channel element 3.7 is not allocated
# [aac @ 0000026f7be58440] channel element 2.1 is not allocated
# [aac @ 0000026f7be58440] channel element 3.10 is not allocated
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] channel element 1.0 is not allocated
# [aac @ 0000026f7be58440] channel element 1.3 is not allocated
# [aac @ 0000026f7be58440] channel element 2.3 is not allocated
# [aac @ 0000026f7be58440] channel element 2.0 is not allocated
# [aac @ 0000026f7be58440] channel element 3.2 is not allocated
# [aac @ 0000026f7be58440] Reserved bit set.
# [aac @ 0000026f7be58440] Number of bands (8) exceeds limit (5).
# [aac @ 0000026f7be58440] channel element 1.4 is not allocated
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] Reserved bit set.
# [aac @ 0000026f7be58440] Number of bands (21) exceeds limit (16).
# [aac @ 0000026f7be58440] channel element 3.7 is not allocated
# [aac @ 0000026f7be58440] Number of bands (51) exceeds limit (36).
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] Number of bands (54) exceeds limit (40).
# [aac @ 0000026f7be58440] channel element 2.7 is not allocated
# [aac @ 0000026f7be58440] channel element 3.15 is not allocated
# [aac @ 0000026f7be58440] SBR was found before the first channel element.
# [aac @ 0000026f7be58440] channel element 1.8 is not allocated
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Prediction is not allowed in AAC-LC.
# [aac @ 0000026f7be58440] channel element 3.5 is not allocated
# [aac @ 0000026f7be58440] channel element 1.2 is not allocated
# [aac @ 0000026f7be58440] channel element 3.2 is not allocated
# [aac @ 0000026f7be58440] channel element 1.9 is not allocated
# [aac @ 0000026f7be58440] channel element 2.1 is not allocated
# [aac @ 0000026f7be58440] skip_data_stream_element: Input buffer exhausted before END element found
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Too large remapped id is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] Number of scalefactor bands in group (53) exceeds limit (47).
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] channel element 3.0 is not allocated
# [aac @ 0000026f7be58440] channel element 1.4 is not allocated
# [aac @ 0000026f7be58440] channel element 1.9 is not allocated
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] channel element 3.15 is not allocated
# [aac @ 0000026f7be58440] Gain control is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] invalid band type
# [aac @ 0000026f7be58440] channel element 3.6 is not allocated
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Too large remapped id is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] Number of bands (10) exceeds limit (9).
# [aac @ 0000026f7be58440] channel element 1.11 is not allocated
# [aac @ 0000026f7be58440] invalid band type
# [aac @ 0000026f7be58440] channel element 2.14 is not allocated
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Too large remapped id is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] channel element 3.8 is not allocated
# [aac @ 0000026f7be58440] channel element 3.4 is not allocated
# [aac @ 0000026f7be58440] channel element 1.2 is not allocated
# [aac @ 0000026f7be58440] Prediction is not allowed in AAC-LC.
# [aac @ 0000026f7be58440] Reserved bit set.
# [aac @ 0000026f7be58440] Number of bands (60) exceeds limit (43).
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] channel element 3.6 is not allocated
# [aac @ 0000026f7be58440] Number of bands (9) exceeds limit (2).
# [aac @ 0000026f7be58440] Number of scalefactor bands in group (53) exceeds limit (47).
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] channel element 3.13 is not allocated
# [aac @ 0000026f7be58440] Dependent coupling is not supported together with LTP
#     Last message repeated 23 times
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Too large remapped id is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] channel element 2.2 is not allocated
# [aac @ 0000026f7be58440] channel element 1.2 is not allocated
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] channel element 2.15 is not allocated
# [aac @ 0000026f7be58440] channel element 2.14 is not allocated
# [aac @ 0000026f7be58440] invalid band type
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Error decoding AAC frame header.
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Too large remapped id is not implemented. Update your FFmpeg version to the newest one from Git. If the problem still occurs, it means that your file has a feature which has not been implemented.
# [aac @ 0000026f7be58440] If you want to help, upload a sample of this file to https://streams.videolan.org/upload/ and contact the ffmpeg-devel mailing list. (ffmpeg-devel@ffmpeg.org)
# [aac @ 0000026f7be58440] Reserved bit set.
# [aac @ 0000026f7be58440] Prediction is not allowed in AAC-LC.
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] channel element 2.2 is not allocated
# [aac @ 0000026f7be58440] Number of bands (62) exceeds limit (46).
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7be58440] Inconsistent channel configuration.
# [aac @ 0000026f7be58440] get_buffer() failed
# [aac @ 0000026f7be58440] Reserved bit set.
# [aac @ 0000026f7be58440] Number of scalefactor bands in group (44) exceeds limit (43).
# ...
# [aac @ 0000026f7f5d0d40] channel element 3.3 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Number of bands (26) exceeds limit (24).
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7f5d0d40] Inconsistent channel configuration.
# [aac @ 0000026f7f5d0d40] get_buffer() failed
# Error while decoding stream #0:0: Invalid argument
# [aac @ 0000026f7f5d0d40] SBR was found before the first channel element.
# [aac @ 0000026f7f5d0d40] Inconsistent channel configuration.
# [aac @ 0000026f7f5d0d40] get_buffer() failed
# Error while decoding stream #0:0: Invalid argument
# [aac @ 0000026f7f5d0d40] Number of bands (14) exceeds limit (12).
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Number of bands (43) exceeds limit (39).
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 1.6 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Number of bands (44) exceeds limit (34).
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Reserved bit set.
# [aac @ 0000026f7f5d0d40] invalid band type
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] SBR was found before the first channel element.
# [aac @ 0000026f7f5d0d40] Number of bands (25) exceeds limit (5).
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 2.0 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 3.7 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 3.11 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Reserved bit set.
# [aac @ 0000026f7f5d0d40] Number of bands (47) exceeds limit (46).
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7f5d0d40] Inconsistent channel configuration.
# [aac @ 0000026f7f5d0d40] get_buffer() failed
# Error while decoding stream #0:0: Invalid argument
# [aac @ 0000026f7f5d0d40] channel element 1.11 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Error decoding AAC frame header.
# Error while decoding stream #0:0: Error number -50531338 occurred
# [aac @ 0000026f7f5d0d40] channel element 2.13 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Number of bands (8) exceeds limit (1).
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 3.14 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Reserved bit set.
# [aac @ 0000026f7f5d0d40] Number of bands (49) exceeds limit (35).
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Number of scalefactor bands in group (63) exceeds limit (40).
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7f5d0d40] Inconsistent channel configuration.
# [aac @ 0000026f7f5d0d40] get_buffer() failed
# Error while decoding stream #0:0: Invalid argument
# [aac @ 0000026f7f5d0d40] Number of scalefactor bands in group (42) exceeds limit (41).
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Error decoding AAC frame header.
# Error while decoding stream #0:0: Error number -50531338 occurred
# [aac @ 0000026f7f5d0d40] channel element 2.0 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 3.7 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Number of bands (50) exceeds limit (36).
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Reserved bit set.
# [aac @ 0000026f7f5d0d40] Number of scalefactor bands in group (58) exceeds limit (40).
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Dependent coupling is not supported together with LTP
#     Last message repeated 16 times
# [aac @ 0000026f7f5d0d40] Number of scalefactor bands in group (60) exceeds limit (40).
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 3.4 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Number of scalefactor bands in group (51) exceeds limit (49).
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 2.11 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 2.4 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Error decoding AAC frame header.
# Error while decoding stream #0:0: Error number -50531338 occurred
# [aac @ 0000026f7f5d0d40] Number of bands (21) exceeds limit (19).
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] skip_data_stream_element: Input buffer exhausted before END element found
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 3.9 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] SBR was found before the first channel element.
# [aac @ 0000026f7f5d0d40] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7f5d0d40] Inconsistent channel configuration.
# [aac @ 0000026f7f5d0d40] get_buffer() failed
# Error while decoding stream #0:0: Invalid argument
# [aac @ 0000026f7f5d0d40] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7f5d0d40] Inconsistent channel configuration.
# [aac @ 0000026f7f5d0d40] get_buffer() failed
# Error while decoding stream #0:0: Invalid argument
# [aac @ 0000026f7f5d0d40] SBR was found before the first channel element.
# [aac @ 0000026f7f5d0d40] channel element 1.2 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Reserved bit set.
# [aac @ 0000026f7f5d0d40] Number of bands (28) exceeds limit (15).
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Number of bands (41) exceeds limit (35).
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Error decoding AAC frame header.
# Error while decoding stream #0:0: Error number -50531338 occurred
# [aac @ 0000026f7f5d0d40] channel element 2.15 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 2.0 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 2.4 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 2.12 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Dependent coupling is not supported together with LTP
#     Last message repeated 14 times
# [aac @ 0000026f7f5d0d40] channel element 3.4 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7f5d0d40] Inconsistent channel configuration.
# [aac @ 0000026f7f5d0d40] get_buffer() failed
# Error while decoding stream #0:0: Invalid argument
# [aac @ 0000026f7f5d0d40] channel element 3.1 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 3.13 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 1.1 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Error decoding AAC frame header.
# Error while decoding stream #0:0: Error number -50531338 occurred
# [aac @ 0000026f7f5d0d40] channel element 3.10 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 1.14 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 1.8 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Reserved bit set.
# [aac @ 0000026f7f5d0d40] Number of scalefactor bands in group (58) exceeds limit (40).
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 1.0 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Reserved bit set.
# [aac @ 0000026f7f5d0d40] invalid band type
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 1.1 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 1.5 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7f5d0d40] Inconsistent channel configuration.
# [aac @ 0000026f7f5d0d40] get_buffer() failed
# Error while decoding stream #0:0: Invalid argument
# [aac @ 0000026f7f5d0d40] Error decoding AAC frame header.
# Error while decoding stream #0:0: Error number -50531338 occurred
# [aac @ 0000026f7f5d0d40] Dependent coupling is not supported together with LTP
#     Last message repeated 14 times
# [aac @ 0000026f7f5d0d40] channel element 3.2 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Number of bands (39) exceeds limit (33).
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 2.9 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7f5d0d40] Inconsistent channel configuration.
# [aac @ 0000026f7f5d0d40] get_buffer() failed
# Error while decoding stream #0:0: Invalid argument
# [aac @ 0000026f7f5d0d40] Number of bands (16) exceeds limit (13).
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 2.12 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Reserved bit set.
# [aac @ 0000026f7f5d0d40] TNS filter order 16 is greater than maximum 12.
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 3.6 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7f5d0d40] Inconsistent channel configuration.
# [aac @ 0000026f7f5d0d40] get_buffer() failed
# Error while decoding stream #0:0: Invalid argument
# [aac @ 0000026f7f5d0d40] channel element 2.14 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 3.0 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 1.6 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Number of bands (37) exceeds limit (19).
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 1.0 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 3.7 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Error decoding AAC frame header.
# Error while decoding stream #0:0: Error number -50531338 occurred
# [aac @ 0000026f7f5d0d40] channel element 1.4 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 1.14 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 2.6 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 3.14 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Reserved bit set.
# [aac @ 0000026f7f5d0d40] Number of bands (28) exceeds limit (22).
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7f5d0d40] decode_pce: Input buffer exhausted before END element found
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Sample rate index in program config element does not match the sample rate index configured by the container.
# [aac @ 0000026f7f5d0d40] Inconsistent channel configuration.
# [aac @ 0000026f7f5d0d40] get_buffer() failed
# Error while decoding stream #0:0: Invalid argument
# [aac @ 0000026f7f5d0d40] channel element 1.2 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] channel element 1.7 is not allocated
# Error while decoding stream #0:0: Invalid data found when processing input
# [aac @ 0000026f7f5d0d40] Error decoding AAC frame header.
# Error while decoding stream #0:0: Error number -50531338 occurred
# [abuffer @ 0000026f7e12c480] Value inf for parameter 'time_base' out of range [0 - 2.14748e+09]
#     Last message repeated 3 times
# [abuffer @ 0000026f7e12c480] Error setting option time_base to value 1/0.
# [graph_0_in_0_0 @ 0000026f7f47ee80] Error applying options to the filter.
# Error reinitializing filters!
# Error while filtering: Result too large
# Finishing stream 0:0 without any data written to it.
# [abuffer @ 0000026f7e12c540] Value inf for parameter 'time_base' out of range [0 - 2.14748e+09]
#     Last message repeated 3 times
# [abuffer @ 0000026f7e12c540] Error setting option time_base to value 1/0.
# [graph_0_in_0_0 @ 0000026f7f66ae80] Error applying options to the filter.
# Error configuring filter graph
# Conversion failed!
